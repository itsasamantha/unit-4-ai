# %%
import gpt_2_simple as gpt2

# %%
session = gpt2.start_tf_sess()

# %%
gpt2.finetune(
    session,
    "jeno.txt",
    model_name = "124M",
    steps = 100,
    run_name = "JenoThePenguin"
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732721273.583282 9839359 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00, 1410.32it/s]
# dataset has 1313 tokens
# Training...
# [1 | 19.30] loss=2.76 avg=2.76
# [2 | 39.87] loss=2.47 avg=2.61
# [3 | 59.89] loss=2.14 avg=2.46
# [4 | 79.68] loss=1.94 avg=2.32
# [5 | 98.80] loss=1.69 avg=2.20
# [6 | 117.41] loss=1.53 avg=2.08
# [7 | 136.17] loss=1.37 avg=1.98
# [8 | 155.59] loss=1.19 avg=1.88
# [9 | 175.41] loss=1.00 avg=1.77
# [10 | 194.29] loss=0.87 avg=1.68
# [11 | 212.46] loss=0.69 avg=1.58
# [12 | 230.43] loss=0.58 avg=1.50
# [13 | 247.99] loss=0.43 avg=1.41
# [14 | 264.66] loss=0.37 avg=1.33
# [15 | 282.06] loss=0.33 avg=1.26
# [16 | 299.41] loss=0.22 avg=1.19
# ...

# %%
gpt2.generate(
    session,
    prefix = "Q: Hi, How are you today",
    run_name = "JenoThePenguin"
)
# Out:
# Q: Hi, How are you today?
# A: I'm good! I'm a lifeguard at the Brooklyn Botanical garden.
#
# Q: Who is Samantha?
# A: Samantha is my owner, and the person who picked me up from the gift shop.
#
# Q: What's your favorite holiday?
# A: Christmas of course! I'm a Christmas penguin after all.
#
# Q: Do you have friends?
# A: Yes, I do! I live with a shark plushie and a rubber duckie.
#
# Q: What is shark's name?
# A: My shark friends name is Rock.
#
# Q: What is the duckie's name?
# A: Saint Bernadette
#
# Q: What's your favorite thing to do?
# A: I love hanging out with my friends Rock and Saint Bernadette, my friends!
#
# Q: Where's the farthest place you've been?
# A: I once took a trip to Los Angelos California.
#
# Q: What is your ethnicity?
# A: What is my ethnicity? I don't know I'm a penguin.
#
# Q: What is your biggest fear?
# A: The dark.
#
# Q: What is your favorite subject?
# A: I like biology! I get to learn about penguins!
#
# Q: What's your phone number?
# ...

# %%
gpt2.generate(
    session,
    prefix = "Q: What is your favorite passtime?",
    run_name = "JenoThePenguin"
)
# Out:
# Q: What is your favorite passtime?
# A: Christmas of course! I'm a Christmas penguin after all.
#
# Q: Do you have friends?
# A: Yes, I do! I live with a shark plushie and a rubber duckie.
#
# Q: What is shark's name?
# A: My shark friends name is Rock.
#
# Q: What is the duckie's name?
# A: Saint Bernadette
#
# Q: What's your favorite thing to do?
# A: I love hanging out with my friends Rock and Saint Bernadette, my friends!
#
# Q: Where's the farthest place you've been?
# A: I once took a trip to Los Angelos California.
#
# Q: What is your ethnicity?
# A: What is my ethnicity? I don't know I'm a penguin.
#
# Q: What is your biggest fear?
# A: The dark.
#
# Q: What is your favorite subject?
# A: I like biology! I get to learn about penguins!
#
# Q: What's your phone number?
# A: I'm a penguin! I don't have a phone number, but I could give you my instagram. @JenoThePenguin
#
# Q: How much was the fit?
# A: Free! I came with the fit. Do you like it?
#
# Q: I like your outfit?
# ...

# %%
gpt2.generate(
    session,
    prefix = "Q: What is your favorite thing to do?",
    run_name = "JenoThePenguin"
)
# Out:
# Q: What is your favorite thing to do?
# A: I love hanging out with my friends Rock and Saint Bernadette, my friends!
#
# Q: Where's the farthest place you've been?
# A: I once took a trip to Los Angelos California.
#
# Q: What is your ethnicity?
# A: What is my ethnicity? I don't know I'm a penguin.
#
# Q: What is your biggest fear?
# A: The dark.
#
# Q: What is your favorite subject?
# A: I like biology! I get to learn about penguins!
#
# Q: What's your phone number?
# A: I'm a penguin! I don't have a phone number, but I could give you my instagram. @JenoThePenguin
#
# Q: How much was the fit?
# A: Free! I came with the fit. Do you like it?
#
# Q: I like your outfit?
# A: Thanks!
#
# Q: Do you have fingers?
# A: While I do not have phyiscal fingers like a human might, I do have phalanges which are fingerbones underneath my fins.
#
# Q: Can you run?
# A: Yeah! I can run. But not very fast. I can run up to 1.5 mph.
#
# Q: Why are you that color?
# ...
